# %%
# imports
import pandas as pd
import numpy as np

# SQL
from sqlalchemy import create_engine, MetaData, Table, Column, Integer, String, Float, inspect
from sqlalchemy.sql import text

# %%
# create filepath
filepath = "Resources/listings_2024.csv"

# read the CSV file
df_2024 = pd.read_csv(filepath, encoding='latin1', low_memory=False)

#view
df_2024.head(10)
# Out:
#                     id                                           name  \
# 0  1189243425411300671                                  The Grand III
# 1   651593916026998398   Cheerful one bedroom townhouse with backyard
# 2               310325            Large Sunny Bedroom with Bay Window
# 3   572612125615500056   Room by Sunny & Bay! Sunset Park & Bay Ridge
# 4  1020282701018874374                         Trendy Private Bedroom
# 5   640443472855597440  Lovely 2 bed/2 bath home with private balcony
# 6   725482656106188093          Gorgeous ! Amazing! Rasta palace â¦.
# 7   681730243323738679                 Lovely one bedroom in Brooklyn
# 8  1004979479809147241                 Beautiful Room in Charming Apt
# 9   969035784970111373                              StuyvesantHieghts
#
#      host_id       host_name neighbourhood_group       neighbourhood  \
# 0   61391963  Stay With Vibe           Manhattan         Murray Hill
# 1  136812643           Marah            Brooklyn           Flatlands
# 2     745069        Kimberly           Manhattan              Harlem
# 3  358089614          Joshua            Brooklyn         Sunset Park
# 4  483056418        Kristina            Brooklyn  Bedford-Stuyvesant
# 5   24278208            Reah            Brooklyn  Bedford-Stuyvesant
# 6    4941291          Randon            Brooklyn  Bedford-Stuyvesant
# 7   45774302          Julian            Brooklyn            Bushwick
# 8  540041298        Kristina              Queens           Ridgewood
# 9  534575586          Walter            Brooklyn  Bedford-Stuyvesant
#
#     latitude  longitude        room_type  price  minimum_nights  \
# 0  40.750251 -73.977745  Entire home/apt   58.0              30
# 1  40.624760 -73.935560     Private room   80.0              30
# 2  40.823590 -73.946010     Private room   75.0              30
# 3  40.639520 -74.014840     Private room   45.0              30
# 4  40.678946 -73.943759     Private room   47.0              30
# 5  40.687400 -73.954970     Private room  194.0              30
# 6  40.680430 -73.957150  Entire home/apt  400.0              30
# 7  40.694410 -73.922970     Private room   79.0              30
# 8  40.702610 -73.904622     Private room   45.0              30
# 9  40.683602 -73.930338  Entire home/apt  225.0              30
#
#    number_of_reviews last_review  reviews_per_month  \
# 0                  1  2024-08-02               0.86
# 1                  0         NaN                NaN
# 2                 31  2019-09-28               0.21
# 3                  6  2024-07-30               0.21
# 4                  0         NaN                NaN
# 5                  0         NaN                NaN
# 6                  0         NaN                NaN
# 7                 14  2023-01-01               0.56
# 8                  0         NaN                NaN
# 9                  5  2023-10-16               0.42
#
#    calculated_host_listings_count  availability_365  number_of_reviews_ltm  \
# 0                             130               357                      1
# 1                               1               365                      0
# 2                               2               335                      0
# 3                               2               336                      1
# 4                              24               269                      0
# 5                               2               323                      0
# 6                               1               364                      0
# 7                               2                89                      0
# 8                               5               260                      0
# 9                               1               180                      5
#
#   license
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN

# %%
# drop columns
df_2024.drop(columns=['name', 'host_id', 'host_name', 'last_review', 'license', 'number_of_reviews_ltm', 'latitude', 'longitude', 'calculated_host_listings_count'], inplace=True)

# %%
# check the drop
df_2024.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37541 entries, 0 to 37540
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   37541 non-null  int64
#  1   neighbourhood_group  37541 non-null  object
#  2   neighbourhood        37541 non-null  object
#  3   room_type            37541 non-null  object
#  4   price                22790 non-null  float64
#  5   minimum_nights       37541 non-null  int64
#  6   number_of_reviews    37541 non-null  int64
#  7   reviews_per_month    26001 non-null  float64
#  8   availability_365     37541 non-null  int64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 2.6+ MB

# %%
# adjust data for some of the null values to still be useful
# if no minimum_nights, change the value to 1
df_2024['minimum_nights'] = df_2024['minimum_nights'].fillna(1)

# if no neighbourhood_group or neighbourhood, change to 'unknown' because the lat and lon will show us later
df_2024['neighbourhood_group'] = df_2024['neighbourhood_group'].fillna('unknown')
df_2024['neighbourhood'] = df_2024['neighbourhood'].fillna('unknown')

# if number of reviews has no information, change the value to 0
df_2024['number_of_reviews'] = df_2024['number_of_reviews'].fillna('0')

df_2024.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37541 entries, 0 to 37540
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   37541 non-null  int64
#  1   neighbourhood_group  37541 non-null  object
#  2   neighbourhood        37541 non-null  object
#  3   room_type            37541 non-null  object
#  4   price                22790 non-null  float64
#  5   minimum_nights       37541 non-null  int64
#  6   number_of_reviews    37541 non-null  int64
#  7   reviews_per_month    26001 non-null  float64
#  8   availability_365     37541 non-null  int64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 2.6+ MB

# %%
# take out the availability 365 column for now...
df_2024.drop(columns=['availability_365', 'reviews_per_month'], inplace=True)
df_2024.head(10)
# Out:
#                     id neighbourhood_group       neighbourhood  \
# 0  1189243425411300671           Manhattan         Murray Hill
# 1   651593916026998398            Brooklyn           Flatlands
# 2               310325           Manhattan              Harlem
# 3   572612125615500056            Brooklyn         Sunset Park
# 4  1020282701018874374            Brooklyn  Bedford-Stuyvesant
# 5   640443472855597440            Brooklyn  Bedford-Stuyvesant
# 6   725482656106188093            Brooklyn  Bedford-Stuyvesant
# 7   681730243323738679            Brooklyn            Bushwick
# 8  1004979479809147241              Queens           Ridgewood
# 9   969035784970111373            Brooklyn  Bedford-Stuyvesant
#
#          room_type  price  minimum_nights  number_of_reviews
# 0  Entire home/apt   58.0              30                  1
# 1     Private room   80.0              30                  0
# 2     Private room   75.0              30                 31
# 3     Private room   45.0              30                  6
# 4     Private room   47.0              30                  0
# 5     Private room  194.0              30                  0
# 6  Entire home/apt  400.0              30                  0
# 7     Private room   79.0              30                 14
# 8     Private room   45.0              30                  0
# 9  Entire home/apt  225.0              30                  5

# %%
# finally, drop the remaining null values that do not include lat/lon or the price
df_2024 = df_2024.dropna()
df_2024.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22790 entries, 0 to 37538
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   22790 non-null  int64
#  1   neighbourhood_group  22790 non-null  object
#  2   neighbourhood        22790 non-null  object
#  3   room_type            22790 non-null  object
#  4   price                22790 non-null  float64
#  5   minimum_nights       22790 non-null  int64
#  6   number_of_reviews    22790 non-null  int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 1.4+ MB

# %%
# Double check the listings are spelled correctly
df_2024.neighbourhood_group.unique()
# Out:
# array(['Manhattan', 'Brooklyn', 'Queens', 'Bronx', 'Staten Island'],
#       dtype=object)

# %%
# save the final df to a new csv for use
df_2024.to_csv("Resources/2024_clean_data_only.csv")
